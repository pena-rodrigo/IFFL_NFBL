# %%
"""
Created on Apr 17 2023

@author: rodrigo pena
"""

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['savefig.dpi'] = 120
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef

torch.manual_seed(0)

import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix

device = torch.device("cpu")
# device = torch.device("cuda:0") # Uncomment this to run on GPU

# %%
ls
# Out:
# classify_IFFL_IFFL_NL.ipynb             iffl_vs_iffl_signal_sigmoid.dat
# classify_IFFL_IFFL_NL_mul.ipynb         iffl_vs_iffl_signal_vars.dat
# classify_IFFL_IFFL_NL_sigmoid.ipynb     iffl_vs_iffl_signal_y.dat
# classify_IFFL_IFFL_NL_vars.ipynb        M1_R1_lbs.dat
# classify_IFFL_IFFL_NL_y.ipynb           M1_R1_signal.dat
# classify_IFFL_NFBL.ipynb                nfbl_vs_nfbl_lbs.dat
# classify_IFFL_NFBL_NL.ipynb             nfbl_vs_nfbl_lbs_mul.dat
# classify_IFFL_NFBL_NL_mul.ipynb         nfbl_vs_nfbl_lbs_sigmoid.dat
# classify_IFFL_NFBL_NL_sigmoid.ipynb     nfbl_vs_nfbl_lbs_vars.dat
# classify_IFFL_NFBL_NL_vars.ipynb        nfbl_vs_nfbl_lbs_y.dat
# classify_IFFL_NFBL_NL_y.ipynb           nfbl_vs_nfbl_signal.dat
# classify_NFLB_NFBL_NL.ipynb             nfbl_vs_nfbl_signal_mul.dat
# classify_NFLB_NFBL_NL_mul.ipynb         nfbl_vs_nfbl_signal_sigmoid.dat
# classify_NFLB_NFBL_NL_sigmoid.ipynb     nfbl_vs_nfbl_signal_vars.dat
# classify_NFLB_NFBL_NL_vars.ipynb        nfbl_vs_nfbl_signal_y.dat
# classify_NFLB_NFBL_NL_y.ipynb           nl_lbs.dat
# gendata_IFFL_NFBL.ipynb                 nl_lbs_mul.dat
# gendata_IFFL_NFBL_multiplicative.ipynb  nl_lbs_sigmoid.dat
# gendata_IFFL_NFBL_sigmoid.ipynb         nl_lbs_vars.dat
# iffl_vs_iffl_lbs.dat                    nl_lbs_y.dat
# iffl_vs_iffl_lbs_mul.dat                nl_signal.dat
# iffl_vs_iffl_lbs_sigmoid.dat            nl_signal_mul.dat
# iffl_vs_iffl_lbs_vars.dat               nl_signal_sigmoid.dat
# iffl_vs_iffl_lbs_y.dat                  nl_signal_vars.dat
# iffl_vs_iffl_signal.dat                 nl_signal_y.dat
# iffl_vs_iffl_signal_mul.dat

# %%
torch.cuda.is_available()
# Out:
# False

# %%
data_cxy = np.loadtxt("iffl_vs_iffl_signal_mul.dat").astype(np.float32)
label_cxy = np.loadtxt("iffl_vs_iffl_lbs_mul.dat").astype(np.float32)
data_cxy = torch.from_numpy(data_cxy)
label_cxy = torch.from_numpy(label_cxy)

# %%
plt.subplot(121)
plt.plot(data_cxy[6])
plt.subplot(122)
plt.plot(data_cxy[7])

# %%
data_cxy[:10]
# Out:
# tensor([[ 1.6190e+00,  7.9100e+00,  1.5312e+00,  9.9980e+01,  1.5734e+00,
#           8.0690e+01,  1.6475e-02, -6.9073e+00,  5.8407e+01],
#         [ 1.6500e+00,  7.3800e+00,  1.4712e+00,  9.9980e+01,  1.5595e+00,
#           9.8940e+01,  1.6507e-02, -6.9535e+00,  5.9964e+01],
#         [ 1.9290e+00,  1.3900e+01,  1.7507e+00,  9.9970e+01,  1.8403e+00,
#           9.1140e+01,  2.7517e-02, -6.2241e+00,  4.7674e+01],
#         [ 1.9281e+00,  8.5400e+00,  1.7186e+00,  9.9980e+01,  1.8226e+00,
#           9.5080e+01,  2.7939e-02, -6.3503e+00,  4.7863e+01],
#         [ 1.8180e+00,  7.4000e+00,  1.5923e+00,  9.9960e+01,  1.7068e+00,
#           2.9070e+01,  2.1870e-02, -5.7704e+00,  4.5261e+01],
#         [ 1.7534e+00,  9.3600e+00,  1.5102e+00,  9.9980e+01,  1.6301e+00,
#           8.7790e+01,  2.0088e-02, -6.2034e+00,  5.1127e+01],
#         [ 1.7699e+00,  6.2200e+00,  1.4339e+00,  9.9980e+01,  1.6007e+00,
#           1.8640e+01,  2.1507e-02, -3.9301e+00,  3.0717e+01],
#         [ 1.8381e+00,  5.6600e+00,  1.4481e+00,  9.9960e+01,  1.6455e+00,
#           1.4430e+01,  1.9967e-02, -4.5615e+00,  3.7115e+01],
#         [ 1.4212e+00,  4.3800e+00,  1.1816e+00,  9.9980e+01,  1.3009e+00,
#           1.8660e+01,  1.1240e-02, -4.5213e+00,  3.8053e+01],
#         [ 1.3485e+00,  5.5600e+00,  1.1229e+00,  9.9970e+01,  1.2332e+00,
#           9.1810e+01,  9.9026e-03, -5.0438e+00,  4.5951e+01]])

# %%
class Net(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.tanh(self.linear1(x))
        x = self.linear2(x)
        return x

class Net_relu(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net_relu,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.relu(self.linear1(x))
        x = self.linear2(x)
        return x
    
class Net_sigmoid(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net_sigmoid,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.sigmoid(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.01
# compare lr with real spk trains
H=10
epochs = 50

model = Net(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net(
#   (linear1): Linear(in_features=9, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
# Print the parameters

print('W: ',list(model.parameters())[0].size())
print('b: ',list(model.parameters())[1].size())
# Out:
# W:  torch.Size([10, 9])
# b:  torch.Size([10])

# %%
my_data_train = []
my_data_val = []
for i in range(len(data_cxy)):
    if i < len(data_cxy)*0.75:
        my_data_train.append([data_cxy[i], label_cxy[i].type(torch.LongTensor)])
    else:    
        my_data_val.append([data_cxy[i], label_cxy[i].type(torch.LongTensor)])

train_set = torch.utils.data.DataLoader(dataset=my_data_train,shuffle=True,batch_size=250)
val_set = torch.utils.data.DataLoader(dataset=my_data_val,shuffle=True,batch_size=250)

# %%
len(val_set)
# Out:
# 4

# %% [markdown]
# # tanh

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)
epochs = 2000

def train_model(n_epochs):
    for epoch in range(n_epochs):
#         print(epoch)
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('tanh.png')
# plt.savefig('tanh.eps')

# %%
accuracy_list[-1]
# Out:
# 0.492

# %% [markdown]
# # ReLU

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.01
# compare lr with real spk trains
H=10
# epochs = 50

model = Net_relu(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net_relu(
#   (linear1): Linear(in_features=9, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)

def train_model(n_epochs):
    for epoch in range(n_epochs):
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
            
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('ghs_relu.png')
# plt.savefig('ghs_relu.eps')

# %%
accuracy_list[-1]
# Out:
# 0.478

# %% [markdown]
# # Sigmoid

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.01
# compare lr with real spk trains
H=10
# epochs = 50

model = Net_sigmoid(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net_sigmoid(
#   (linear1): Linear(in_features=9, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)

def train_model(n_epochs):
    for epoch in range(n_epochs):
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
            
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('ghs_sigmoid.png')
# plt.savefig('ghs_sigmoid.eps')

# %%
accuracy_list[-1]
# Out:
# 0.492
