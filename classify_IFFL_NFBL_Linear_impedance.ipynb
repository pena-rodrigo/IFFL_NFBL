# %%
"""
Created on Apr 17 2023

@author: rodrigo pena
"""

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['savefig.dpi'] = 120
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef

torch.manual_seed(0)

import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix

device = torch.device("cpu")
# device = torch.device("cuda:0") # Uncomment this to run on GPU

# %%
ls
# Out:
# classify_IFFL_IFFL_NL.ipynb                nfbl_vs_nfbl_lbs39.dat
# classify_IFFL_IFFL_NL_mul.ipynb            nfbl_vs_nfbl_lbs3.dat
# classify_IFFL_IFFL_NL_sigmoid.ipynb        nfbl_vs_nfbl_lbs4.dat
# classify_IFFL_IFFL_NL_vars.ipynb           nfbl_vs_nfbl_lbs5.dat
# classify_IFFL_IFFL_NL_y.ipynb              nfbl_vs_nfbl_lbs6.dat
# classify_IFFL_NFBL.ipynb                   nfbl_vs_nfbl_lbs7.dat
# classify_IFFL_NFBL_Linear_impedance.ipynb  nfbl_vs_nfbl_lbs8.dat
# classify_IFFL_NFBL_Linear.ipynb            nfbl_vs_nfbl_lbs9.dat
# classify_IFFL_NFBL_NL.ipynb                nfbl_vs_nfbl_lbs.dat
# classify_IFFL_NFBL_NL_mul.ipynb            nfbl_vs_nfbl_lbs_mul.dat
# classify_IFFL_NFBL_NL_noise.ipynb          nfbl_vs_nfbl_lbs_sigmoid.dat
# classify_IFFL_NFBL_NL_sigmoid.ipynb        nfbl_vs_nfbl_lbs_vars.dat
# classify_IFFL_NFBL_NL_vars.ipynb           nfbl_vs_nfbl_lbs_y.dat
# classify_IFFL_NFBL_NL_y.ipynb              nfbl_vs_nfbl_signal0.dat
# classify_NFLB_NFBL_NL.ipynb                nfbl_vs_nfbl_signal10.dat
# classify_NFLB_NFBL_NL_mul.ipynb            nfbl_vs_nfbl_signal11.dat
# classify_NFLB_NFBL_NL_sigmoid.ipynb        nfbl_vs_nfbl_signal12.dat
# classify_NFLB_NFBL_NL_vars.ipynb           nfbl_vs_nfbl_signal13.dat
# classify_NFLB_NFBL_NL_y.ipynb              nfbl_vs_nfbl_signal14.dat
# gendata_IFFL_NFBL_impedance.ipynb          nfbl_vs_nfbl_signal15.dat
# gendata_IFFL_NFBL.ipynb                    nfbl_vs_nfbl_signal16.dat
# gendata_IFFL_NFBL_Linear.ipynb             nfbl_vs_nfbl_signal17.dat
# gendata_IFFL_NFBL_multiplicative.ipynb     nfbl_vs_nfbl_signal18.dat
# gendata_IFFL_NFBL_noise.ipynb              nfbl_vs_nfbl_signal19.dat
# gendata_IFFL_NFBL_sigmoid.ipynb            nfbl_vs_nfbl_signal1.dat
# iffl_vs_iffl_lbs0.dat                      nfbl_vs_nfbl_signal20.dat
# iffl_vs_iffl_lbs10.dat                     nfbl_vs_nfbl_signal21.dat
# iffl_vs_iffl_lbs11.dat                     nfbl_vs_nfbl_signal22.dat
# iffl_vs_iffl_lbs12.dat                     nfbl_vs_nfbl_signal23.dat
# iffl_vs_iffl_lbs13.dat                     nfbl_vs_nfbl_signal24.dat
# iffl_vs_iffl_lbs14.dat                     nfbl_vs_nfbl_signal25.dat
# iffl_vs_iffl_lbs15.dat                     nfbl_vs_nfbl_signal26.dat
# iffl_vs_iffl_lbs16.dat                     nfbl_vs_nfbl_signal27.dat
# iffl_vs_iffl_lbs17.dat                     nfbl_vs_nfbl_signal28.dat
# iffl_vs_iffl_lbs18.dat                     nfbl_vs_nfbl_signal29.dat
# iffl_vs_iffl_lbs19.dat                     nfbl_vs_nfbl_signal2.dat
# iffl_vs_iffl_lbs1.dat                      nfbl_vs_nfbl_signal30.dat
# iffl_vs_iffl_lbs20.dat                     nfbl_vs_nfbl_signal31.dat
# iffl_vs_iffl_lbs21.dat                     nfbl_vs_nfbl_signal32.dat
# iffl_vs_iffl_lbs22.dat                     nfbl_vs_nfbl_signal33.dat
# iffl_vs_iffl_lbs23.dat                     nfbl_vs_nfbl_signal34.dat
# iffl_vs_iffl_lbs24.dat                     nfbl_vs_nfbl_signal35.dat
# iffl_vs_iffl_lbs25.dat                     nfbl_vs_nfbl_signal36.dat
# iffl_vs_iffl_lbs26.dat                     nfbl_vs_nfbl_signal37.dat
# iffl_vs_iffl_lbs27.dat                     nfbl_vs_nfbl_signal38.dat
# iffl_vs_iffl_lbs28.dat                     nfbl_vs_nfbl_signal39.dat
# iffl_vs_iffl_lbs29.dat                     nfbl_vs_nfbl_signal3.dat
# iffl_vs_iffl_lbs2.dat                      nfbl_vs_nfbl_signal4.dat
# iffl_vs_iffl_lbs30.dat                     nfbl_vs_nfbl_signal5.dat
# iffl_vs_iffl_lbs31.dat                     nfbl_vs_nfbl_signal6.dat
# iffl_vs_iffl_lbs32.dat                     nfbl_vs_nfbl_signal7.dat
# iffl_vs_iffl_lbs33.dat                     nfbl_vs_nfbl_signal8.dat
# iffl_vs_iffl_lbs34.dat                     nfbl_vs_nfbl_signal9.dat
# iffl_vs_iffl_lbs35.dat                     nfbl_vs_nfbl_signal.dat
# iffl_vs_iffl_lbs36.dat                     nfbl_vs_nfbl_signal_mul.dat
# iffl_vs_iffl_lbs37.dat                     nfbl_vs_nfbl_signal_sigmoid.dat
# iffl_vs_iffl_lbs38.dat                     nfbl_vs_nfbl_signal_vars.dat
# iffl_vs_iffl_lbs39.dat                     nfbl_vs_nfbl_signal_y.dat
# iffl_vs_iffl_lbs3.dat                      nl_lbs0.dat
# iffl_vs_iffl_lbs4.dat                      nl_lbs10.dat
# iffl_vs_iffl_lbs5.dat                      nl_lbs11.dat
# iffl_vs_iffl_lbs6.dat                      nl_lbs12.dat
# iffl_vs_iffl_lbs7.dat                      nl_lbs13.dat
# iffl_vs_iffl_lbs8.dat                      nl_lbs14.dat
# iffl_vs_iffl_lbs9.dat                      nl_lbs15.dat
# iffl_vs_iffl_lbs.dat                       nl_lbs16.dat
# iffl_vs_iffl_lbs_mul.dat                   nl_lbs17.dat
# iffl_vs_iffl_lbs_sigmoid.dat               nl_lbs18.dat
# iffl_vs_iffl_lbs_vars.dat                  nl_lbs19.dat
# iffl_vs_iffl_lbs_y.dat                     nl_lbs1.dat
# iffl_vs_iffl_signal0.dat                   nl_lbs20.dat
# iffl_vs_iffl_signal10.dat                  nl_lbs21.dat
# iffl_vs_iffl_signal11.dat                  nl_lbs22.dat
# iffl_vs_iffl_signal12.dat                  nl_lbs23.dat
# iffl_vs_iffl_signal13.dat                  nl_lbs24.dat
# iffl_vs_iffl_signal14.dat                  nl_lbs25.dat
# iffl_vs_iffl_signal15.dat                  nl_lbs26.dat
# iffl_vs_iffl_signal16.dat                  nl_lbs27.dat
# iffl_vs_iffl_signal17.dat                  nl_lbs28.dat
# iffl_vs_iffl_signal18.dat                  nl_lbs29.dat
# iffl_vs_iffl_signal19.dat                  nl_lbs2.dat
# iffl_vs_iffl_signal1.dat                   nl_lbs30.dat
# iffl_vs_iffl_signal20.dat                  nl_lbs31.dat
# iffl_vs_iffl_signal21.dat                  nl_lbs32.dat
# iffl_vs_iffl_signal22.dat                  nl_lbs33.dat
# iffl_vs_iffl_signal23.dat                  nl_lbs34.dat
# iffl_vs_iffl_signal24.dat                  nl_lbs35.dat
# iffl_vs_iffl_signal25.dat                  nl_lbs36.dat
# iffl_vs_iffl_signal26.dat                  nl_lbs37.dat
# iffl_vs_iffl_signal27.dat                  nl_lbs38.dat
# iffl_vs_iffl_signal28.dat                  nl_lbs39.dat
# iffl_vs_iffl_signal29.dat                  nl_lbs3.dat
# iffl_vs_iffl_signal2.dat                   nl_lbs4.dat
# iffl_vs_iffl_signal30.dat                  nl_lbs5.dat
# iffl_vs_iffl_signal31.dat                  nl_lbs6.dat
# iffl_vs_iffl_signal32.dat                  nl_lbs7.dat
# iffl_vs_iffl_signal33.dat                  nl_lbs8.dat
# iffl_vs_iffl_signal34.dat                  nl_lbs9.dat
# iffl_vs_iffl_signal35.dat                  nl_lbs.dat
# iffl_vs_iffl_signal36.dat                  nl_lbs_Impedance.dat
# iffl_vs_iffl_signal37.dat                  nl_lbs_mul.dat
# iffl_vs_iffl_signal38.dat                  nl_lbs_sigmoid.dat
# iffl_vs_iffl_signal39.dat                  nl_lbs_vars.dat
# iffl_vs_iffl_signal3.dat                   nl_lbs_y.dat
# iffl_vs_iffl_signal4.dat                   nl_signal0.dat
# iffl_vs_iffl_signal5.dat                   nl_signal10.dat
# iffl_vs_iffl_signal6.dat                   nl_signal11.dat
# iffl_vs_iffl_signal7.dat                   nl_signal12.dat
# iffl_vs_iffl_signal8.dat                   nl_signal13.dat
# iffl_vs_iffl_signal9.dat                   nl_signal14.dat
# iffl_vs_iffl_signal.dat                    nl_signal15.dat
# iffl_vs_iffl_signal_mul.dat                nl_signal16.dat
# iffl_vs_iffl_signal_sigmoid.dat            nl_signal17.dat
# iffl_vs_iffl_signal_vars.dat               nl_signal18.dat
# iffl_vs_iffl_signal_y.dat                  nl_signal19.dat
# linear_lbs.dat                             nl_signal1.dat
# linear_signal.dat                          nl_signal20.dat
# M1_R1_lbs.dat                              nl_signal21.dat
# M1_R1_signal.dat                           nl_signal22.dat
# nfbl_vs_nfbl_lbs0.dat                      nl_signal23.dat
# nfbl_vs_nfbl_lbs10.dat                     nl_signal24.dat
# nfbl_vs_nfbl_lbs11.dat                     nl_signal25.dat
# nfbl_vs_nfbl_lbs12.dat                     nl_signal26.dat
# nfbl_vs_nfbl_lbs13.dat                     nl_signal27.dat
# nfbl_vs_nfbl_lbs14.dat                     nl_signal28.dat
# nfbl_vs_nfbl_lbs15.dat                     nl_signal29.dat
# nfbl_vs_nfbl_lbs16.dat                     nl_signal2.dat
# nfbl_vs_nfbl_lbs17.dat                     nl_signal30.dat
# nfbl_vs_nfbl_lbs18.dat                     nl_signal31.dat
# nfbl_vs_nfbl_lbs19.dat                     nl_signal32.dat
# nfbl_vs_nfbl_lbs1.dat                      nl_signal33.dat
# nfbl_vs_nfbl_lbs20.dat                     nl_signal34.dat
# nfbl_vs_nfbl_lbs21.dat                     nl_signal35.dat
# nfbl_vs_nfbl_lbs22.dat                     nl_signal36.dat
# nfbl_vs_nfbl_lbs23.dat                     nl_signal37.dat
# nfbl_vs_nfbl_lbs24.dat                     nl_signal38.dat
# nfbl_vs_nfbl_lbs25.dat                     nl_signal39.dat
# nfbl_vs_nfbl_lbs26.dat                     nl_signal3.dat
# nfbl_vs_nfbl_lbs27.dat                     nl_signal4.dat
# nfbl_vs_nfbl_lbs28.dat                     nl_signal5.dat
# nfbl_vs_nfbl_lbs29.dat                     nl_signal6.dat
# nfbl_vs_nfbl_lbs2.dat                      nl_signal7.dat
# nfbl_vs_nfbl_lbs30.dat                     nl_signal8.dat
# nfbl_vs_nfbl_lbs31.dat                     nl_signal9.dat
# nfbl_vs_nfbl_lbs32.dat                     nl_signal.dat
# nfbl_vs_nfbl_lbs33.dat                     nl_signal_Impedance.dat
# nfbl_vs_nfbl_lbs34.dat                     nl_signal_mul.dat
# nfbl_vs_nfbl_lbs35.dat                     nl_signal_sigmoid.dat
# nfbl_vs_nfbl_lbs36.dat                     nl_signal_vars.dat
# nfbl_vs_nfbl_lbs37.dat                     nl_signal_y.dat
# nfbl_vs_nfbl_lbs38.dat

# %%
torch.cuda.is_available()
# Out:
# False

# %%
data_cxy = np.loadtxt("nl_signal_Impedance.dat").astype(np.float32)
label_cxy = np.loadtxt("nl_lbs_Impedance.dat").astype(np.float32)
data_cxy = torch.from_numpy(data_cxy)
label_cxy = torch.from_numpy(label_cxy)

# %%
plt.subplot(121)
plt.plot(data_cxy[6])
plt.subplot(122)
plt.plot(data_cxy[7])

# %%
data_cxy
# Out:
# tensor([[1.9581e+01, 1.0250e+03],
#         [2.2918e+01, 6.2000e+01],
#         [1.7796e+01, 8.5800e+02],
#         ...,
#         [1.9390e+01, 2.8200e+02],
#         [1.7597e+01, 7.4900e+02],
#         [1.9583e+01, 1.0000e+00]])

# %%
label_cxy
# Out:
# tensor([0., 1., 0.,  ..., 1., 0., 1.])

# %%
class Net(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.tanh(self.linear1(x))
        x = self.linear2(x)
        return x

class Net_relu(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net_relu,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.relu(self.linear1(x))
        x = self.linear2(x)
        return x
    
class Net_sigmoid(nn.Module):
    def __init__(self,D_in,H,D_out):
        super(Net_sigmoid,self).__init__()
        self.linear1 = nn.Linear(D_in,H)
        self.linear2 = nn.Linear(H,D_out)
        
    def forward(self,x):
        x = torch.sigmoid(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.001
# compare lr with real spk trains
H=10
epochs = 50

model = Net(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net(
#   (linear1): Linear(in_features=2, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
# Print the parameters

print('W: ',list(model.parameters())[0].size())
print('b: ',list(model.parameters())[1].size())
# Out:
# W:  torch.Size([10, 2])
# b:  torch.Size([10])

# %%
my_data_train = []
my_data_val = []
for i in range(len(data_cxy)):
    if i < len(data_cxy)*0.75:
        my_data_train.append([data_cxy[i], label_cxy[i].type(torch.LongTensor)])
    else:    
        my_data_val.append([data_cxy[i], label_cxy[i].type(torch.LongTensor)])

train_set = torch.utils.data.DataLoader(dataset=my_data_train,shuffle=True,batch_size=250)
val_set = torch.utils.data.DataLoader(dataset=my_data_val,shuffle=True,batch_size=250)

# %%
len(val_set)
# Out:
# 4

# %% [markdown]
# # tanh

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)
epochs = 2000

def train_model(n_epochs):
    for epoch in range(n_epochs):
#         print(epoch)
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('tanh.png')
# plt.savefig('tanh.eps')

# %%
accuracy_list[-1]
# Out:
# 0.941

# %% [markdown]
# # ReLU

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.001
# compare lr with real spk trains
H=10
# epochs = 50

model = Net_relu(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net_relu(
#   (linear1): Linear(in_features=2, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)

def train_model(n_epochs):
    for epoch in range(n_epochs):
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
            
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('ghs_relu.png')
# plt.savefig('ghs_relu.eps')

# %%
accuracy_list[-1]
# Out:
# 0.945

# %% [markdown]
# # Sigmoid

# %%
input_dim = len(data_cxy[0])
output_dim = 2
learning_rate=0.001
# compare lr with real spk trains
H=10
# epochs = 50

model = Net_sigmoid(input_dim,H,output_dim)
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate, momentum=0.2)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# Net_sigmoid(
#   (linear1): Linear(in_features=2, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
loss_list = []
accuracy_list = []
N_test = len(my_data_val)

def train_model(n_epochs):
    for epoch in range(n_epochs):
        for x,y in train_set:
            optimizer.zero_grad()
            z = model(x)
            loss = criterion(z,y)
            loss.backward()
            optimizer.step()
            
        correct = 0
        for x_test, y_test in val_set:
            z = model(x_test)
            _, yhat = torch.max(z.data,1)
            correct += (yhat == y_test).sum().item()
        accuracy = correct / N_test
        loss_list.append(loss.data)
        accuracy_list.append(accuracy)
train_model(epochs)

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:cyan'
ax1.plot(loss_list,color=color,alpha=0.5)
ax1.set_xlabel('Epoch',color=color)
ax1.set_ylabel('Cross-entropy loss',color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Accuracy', color=color)  
ax2.plot( accuracy_list, color=color,alpha=1)
ax2.tick_params(axis='y', color=color)
# fig.tight_layout()
plt.xlim([-10,epochs])
plt.locator_params(axis='x', nbins=8)
for item in ([ax1.title, ax1.xaxis.label, ax1.yaxis.label] +
             ax1.get_xticklabels() + ax1.get_yticklabels() + 
            [ax2.title, ax2.xaxis.label, ax2.yaxis.label] +
             ax2.get_xticklabels() + ax2.get_yticklabels()):
    item.set_fontsize(20)

# plt.savefig('ghs_sigmoid.png')
# plt.savefig('ghs_sigmoid.eps')

# %%
accuracy_list[-1]
# Out:
# 0.939
